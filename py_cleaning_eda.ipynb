# %%
import pandas as pd
import numpy as np
import os
from datetime import date, datetime
from dateutil.relativedelta import relativedelta

# %%
base_path = './data/'

customer_filename = 'customers.csv'
product_filename = 'product_usage.tsv'
subscription_filename = 'subscriptions.json'
support_filename = 'support_tickets.csv'

# %%
customer_df = pd.read_csv(os.path.join(base_path, customer_filename))
product_df = pd.read_csv(os.path.join(base_path, product_filename), sep='\t')
subscription_df = pd.read_json(os.path.join(base_path, subscription_filename))
support_ticket_df = pd.read_csv(os.path.join(base_path, support_filename))

# %%
# keeping copies of original data for fail-safe conditions
customer_df_original = customer_df.copy()
product_df_original = product_df.copy()
subscription_df_original = subscription_df.copy()
support_ticket_df_original = support_ticket_df.copy()

# %%
customer_df.head(3)
# Out:
#    customer_id        name signup_date    industry   plan       location
# 0            1  Customer_1  2023-10-17     Fintech  Basic            NaN
# 1            2  Customer_2  2022-10-09  E-commerce    Pro  San Francisco
# 2            3  Customer_3  2022-04-15         NaN  Basic         London

# %%
product_df.head(3)
# Out:
#    customer_id  usage_date features_used  minutes_spent errors_reported
# 0           34  2024/03/31        Upload          59.90               1
# 1           97  2024/04/25       Reports          40.85               0
# 2          190  2024/05/16        Export          53.37               1

# %%
subscription_df.head(3)
# Out:
#    customer_id subscription_id  start_date    end_date    status  \
# 0            1           sub_1  28-06-2023  20-01-2024    active
# 1            2           sub_2  27-12-2022  15-09-2023    active
# 2            3           sub_3  25-08-2022  24-11-2022  inactive
#
#   payment_method
# 0            upi
# 1            upi
# 2            upi

# %%
support_ticket_df.head(3)
# Out:
#   ticket_id  customer_id       issue_type opened_date resolved_date  \
# 0    TCKT-1           81  Feature Request  2023-02-03    2023-02-03
# 1    TCKT-2           83      Login Issue  2023-02-09    2023-02-11
# 2    TCKT-3          177              Bug  2023-10-13    2023-10-24
#
#    satisfaction_score
# 0                 4.0
# 1                 NaN
# 2                 NaN

# %% [markdown]
# ##### Let's cleanup one by one

# %%
customer_df
# Out:
#      customer_id          name signup_date    industry        plan  \
# 0              1    Customer_1  2023-10-17     Fintech       Basic
# 1              2    Customer_2  2022-10-09  E-commerce         Pro
# 2              3    Customer_3  2022-04-15         NaN       Basic
# 3              4    Customer_4  2023-03-09     Fintech       Basic
# 4              5    Customer_5  2022-08-12  E-commerce       Basic
# ..           ...           ...         ...         ...         ...
# 195          196  Customer_196  2023-07-23  E-commerce         NaN
# 196          197  Customer_197  2023-12-30   Education         NaN
# 197          198  Customer_198  2022-04-06  Healthcare         Pro
# 198          199  Customer_199  2023-12-10  E-commerce  Enterprise
# 199          200  Customer_200  2023-08-19  Healthcare         NaN
#
#           location
# 0              NaN
# 1    San Francisco
# 2           London
# 3         New York
# 4           London
# ..             ...
# 195            NaN
# 196       New York
# 197         Berlin
# 198            NaN
# 199         London
#
# [200 rows x 6 columns]

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  200 non-null    int64
#  1   name         185 non-null    object
#  2   signup_date  189 non-null    object
#  3   industry     162 non-null    object
#  4   plan         153 non-null    object
#  5   location     165 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB

# %%
customer_df.isna().sum()
# Out:
# customer_id     0
# name           15
# signup_date    11
# industry       38
# plan           47
# location       35
# dtype: int64

# %%
# dropping rows where all the values are blank
customer_df.dropna(how='all')
# Out:
#      customer_id          name signup_date    industry        plan  \
# 0              1    Customer_1  2023-10-17     Fintech       Basic
# 1              2    Customer_2  2022-10-09  E-commerce         Pro
# 2              3    Customer_3  2022-04-15         NaN       Basic
# 3              4    Customer_4  2023-03-09     Fintech       Basic
# 4              5    Customer_5  2022-08-12  E-commerce       Basic
# ..           ...           ...         ...         ...         ...
# 195          196  Customer_196  2023-07-23  E-commerce         NaN
# 196          197  Customer_197  2023-12-30   Education         NaN
# 197          198  Customer_198  2022-04-06  Healthcare         Pro
# 198          199  Customer_199  2023-12-10  E-commerce  Enterprise
# 199          200  Customer_200  2023-08-19  Healthcare         NaN
#
#           location
# 0              NaN
# 1    San Francisco
# 2           London
# 3         New York
# 4           London
# ..             ...
# 195            NaN
# 196       New York
# 197         Berlin
# 198            NaN
# 199         London
#
# [200 rows x 6 columns]

# %%
# checking duplicate values based on PK column, i.e. (customer_id, name)
customer_df[customer_df.duplicated(subset=['customer_id', 'name'])]
# Out:
# Empty DataFrame
# Columns: [customer_id, name, signup_date, industry, plan, location]
# Index: []

# %%
# checking for nulls in the customer column
customer_df[customer_df['name'].isna()]
# Out:
#      customer_id name signup_date    industry        plan       location
# 12            13  NaN  2022-03-22        SaaS  Enterprise            NaN
# 25            26  NaN  2023-11-03   Education         NaN            NaN
# 38            39  NaN  2022-07-02        SaaS       Basic            NaN
# 51            52  NaN  2023-08-26        SaaS         Pro         London
# 64            65  NaN  2022-10-13   Education         Pro       New York
# 77            78  NaN  2023-09-02     Fintech         Pro         Berlin
# 90            91  NaN  2023-07-22  Healthcare       Basic  San Francisco
# 103          104  NaN  2022-02-10  Healthcare         Pro            NaN
# 116          117  NaN  2022-09-25  E-commerce  Enterprise       New York
# 129          130  NaN  2023-07-16     Fintech  Enterprise      Bangalore
# 142          143  NaN  2022-09-13     Fintech         NaN  San Francisco
# 155          156  NaN  2023-08-22         NaN       Basic         London
# 168          169  NaN  2022-09-16     Fintech         NaN       New York
# 181          182  NaN  2023-01-15     Fintech  Enterprise       New York
# 194          195  NaN  2022-09-05         NaN         NaN         Berlin

# %%
# replacing the missing customer names using other name patterns available
customer_df.loc[customer_df['name'].isna(), 'name'] = 'Customer_' + customer_df['customer_id'].astype(str)

# %%
# conversion to datetime object for future operations
customer_df['signup_date'] = pd.to_datetime(customer_df['signup_date'], errors='coerce', format='%Y-%m-%d')

# %%
customer_df['signup_date'].head()
# Out:
# 0   2023-10-17
# 1   2022-10-09
# 2   2022-04-15
# 3   2023-03-09
# 4   2022-08-12
# Name: signup_date, dtype: datetime64[ns]

# %%
print(customer_df['industry'].unique())
print(customer_df['plan'].unique())
print(customer_df['location'].unique())
# Out:
# ['Fintech' 'E-commerce' nan 'SaaS' 'Healthcare' 'Education']
# ['Basic' 'Pro' nan 'Enterprise']
# [nan 'San Francisco' 'London' 'New York' 'Bangalore' 'Berlin']

# %%
customer_df['industry'] = customer_df['industry'].str.strip()
customer_df['plan'] = customer_df['plan'].str.strip()
customer_df['location'] = customer_df['location'].str.strip()

# %%
customer_df['plan'].fillna('Unknown', inplace=True)
customer_df['industry'].fillna('Unknown', inplace=True)
customer_df['location'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_2568\3135988210.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer_df['plan'].fillna('Unknown', inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_2568\3135988210.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer_df['industry'].fillna('Unknown', inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_2568\3135988210.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer_df['location'].fillna('Unknown', inplace=True)

# %%
customer_df
# Out:
#      customer_id          name signup_date    industry        plan  \
# 0              1    Customer_1  2023-10-17     Fintech       Basic
# 1              2    Customer_2  2022-10-09  E-commerce         Pro
# 2              3    Customer_3  2022-04-15     Unknown       Basic
# 3              4    Customer_4  2023-03-09     Fintech       Basic
# 4              5    Customer_5  2022-08-12  E-commerce       Basic
# ..           ...           ...         ...         ...         ...
# 195          196  Customer_196  2023-07-23  E-commerce     Unknown
# 196          197  Customer_197  2023-12-30   Education     Unknown
# 197          198  Customer_198  2022-04-06  Healthcare         Pro
# 198          199  Customer_199  2023-12-10  E-commerce  Enterprise
# 199          200  Customer_200  2023-08-19  Healthcare     Unknown
#
#           location
# 0          Unknown
# 1    San Francisco
# 2           London
# 3         New York
# 4           London
# ..             ...
# 195        Unknown
# 196       New York
# 197         Berlin
# 198        Unknown
# 199         London
#
# [200 rows x 6 columns]

# %% [markdown]
# #### Products

# %%
product_df
# Out:
#       customer_id  usage_date features_used  minutes_spent errors_reported
# 0              34  2024/03/31        Upload          59.90               1
# 1              97  2024/04/25       Reports          40.85               0
# 2             190  2024/05/16        Export          53.37               1
# 3             131  2023/12/03     Dashboard          75.32               2
# 4              55  2023/11/22        Alerts          31.10               0
# ...           ...         ...           ...            ...             ...
# 4995           19  2024/03/29           API          48.72               0
# 4996          118  2023/06/21           API          97.74               0
# 4997           76  2023/11/06       Reports          61.82               1
# 4998          156  2023/06/01       Reports           3.92           error
# 4999          192  2024/02/29        Alerts          97.94               3
#
# [5000 rows x 5 columns]

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      5000 non-null   int64
#  1   usage_date       5000 non-null   object
#  2   features_used    5000 non-null   object
#  3   minutes_spent    5000 non-null   float64
#  4   errors_reported  5000 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 195.4+ KB

# %%
product_df.isna().sum()
# Out:
# customer_id        0
# usage_date         0
# features_used      0
# minutes_spent      0
# errors_reported    0
# dtype: int64

# %%
product_df['usage_date'] = pd.to_datetime(product_df['usage_date'], format='%Y/%m/%d')

# %%
product_df['errors_reported'].unique()
# Out:
# array(['1', '0', '2', 'error', '4', '3', '5'], dtype=object)

# %%
product_df[product_df['errors_reported'] == 'error']
# Out:
#       customer_id usage_date features_used  minutes_spent errors_reported
# 6             198 2024-03-03        Upload           6.75           error
# 33            163 2023-12-16       Reports          43.17           error
# 45            133 2023-10-15     Dashboard          52.83           error
# 52            156 2024-05-13     Alerts###          12.82           error
# 65             52 2023-08-11           API          71.21           error
# ...           ...        ...           ...            ...             ...
# 4984          169 2023-12-04           API           5.67           error
# 4987          188 2024-04-24       Reports           0.75           error
# 4990          159 2023-11-09        Alerts          62.08           error
# 4991          126 2024-02-09           API          46.58           error
# 4998          156 2023-06-01       Reports           3.92           error
#
# [514 rows x 5 columns]

# %%
product_df['errors_reported'] = pd.to_numeric(product_df['errors_reported'], errors='coerce')

# %%
product_df['features_used'].unique()
# Out:
# array(['Upload', 'Reports', 'Export', 'Dashboard', 'Alerts', 'Alerts###',
#        'API', 'Dashboard###', 'API###', 'Reports###', 'Upload###',
#        'Export###'], dtype=object)

# %%
product_df['features_used'] = product_df['features_used'].str.replace(r'[^a-zA-Z ]', '', regex=True).str.strip()

# %%
product_df['features_used'].unique()
# Out:
# array(['Upload', 'Reports', 'Export', 'Dashboard', 'Alerts', 'API'],
#       dtype=object)

# %%
product_df
# Out:
#       customer_id usage_date features_used  minutes_spent  errors_reported
# 0              34 2024-03-31        Upload          59.90              1.0
# 1              97 2024-04-25       Reports          40.85              0.0
# 2             190 2024-05-16        Export          53.37              1.0
# 3             131 2023-12-03     Dashboard          75.32              2.0
# 4              55 2023-11-22        Alerts          31.10              0.0
# ...           ...        ...           ...            ...              ...
# 4995           19 2024-03-29           API          48.72              0.0
# 4996          118 2023-06-21           API          97.74              0.0
# 4997           76 2023-11-06       Reports          61.82              1.0
# 4998          156 2023-06-01       Reports           3.92              NaN
# 4999          192 2024-02-29        Alerts          97.94              3.0
#
# [5000 rows x 5 columns]

# %%
product_df[~(product_df['customer_id'].isin(customer_df['customer_id']))]
# Out:
# Empty DataFrame
# Columns: [customer_id, usage_date, features_used, minutes_spent, errors_reported]
# Index: []

# %% [markdown]
# #### Subscriptions

# %%
subscription_df
# Out:
#      customer_id subscription_id  start_date    end_date     status  \
# 0              1           sub_1  28-06-2023  20-01-2024     active
# 1              2           sub_2  27-12-2022  15-09-2023     active
# 2              3           sub_3  25-08-2022  24-11-2022   inactive
# 3              4           sub_4  03-05-2022  03-03-2023  cancelled
# 4              5           sub_5  16-07-2022  03-12-2022   inactive
# ..           ...             ...         ...         ...        ...
# 195          196         sub_196  09-10-2023  04-10-2024     active
# 196          197         sub_197  07-04-2022  16-02-2023   inactive
# 197          198         sub_198  16-09-2022        None   inactive
# 198          199         sub_199  25-03-2022  16-02-2023   inactive
# 199          200         sub_200  14-11-2022  14-11-2023   inactive
#
#     payment_method
# 0              upi
# 1              upi
# 2              upi
# 3           paypal
# 4              upi
# ..             ...
# 195            upi
# 196            upi
# 197            upi
# 198            upi
# 199           None
#
# [200 rows x 6 columns]

# %%
subscription_df.isna().sum()
# Out:
# customer_id         0
# subscription_id     0
# start_date          0
# end_date           18
# status              0
# payment_method     48
# dtype: int64

# %%
subscription_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking if there's any row hab=ving all blank values
subscription_df[subscription_df.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [customer_id, subscription_id, start_date, end_date, status, payment_method]
# Index: []

# %%
subscription_df['start_date'] = pd.to_datetime(subscription_df['start_date'], format='%d-%m-%Y')
subscription_df['end_date'] = pd.to_datetime(subscription_df['end_date'], format='%d-%m-%Y')

# %%
subscription_df['status'].unique()
# Out:
# array(['active', 'inactive', 'cancelled'], dtype=object)

# %%
subscription_df['payment_method'].unique()
# Out:
# array(['upi', 'paypal', 'credit_card', None], dtype=object)

# %%
subscription_df[~(subscription_df['customer_id'].isin(customer_df['customer_id']))]
# Out:
# Empty DataFrame
# Columns: [customer_id, subscription_id, start_date, end_date, status, payment_method]
# Index: []

# %% [markdown]
# #### Support Tickets

# %%
support_ticket_df
# Out:
#     ticket_id  customer_id       issue_type opened_date resolved_date  \
# 0      TCKT-1           81  Feature Request  2023-02-03    2023-02-03
# 1      TCKT-2           83      Login Issue  2023-02-09    2023-02-11
# 2      TCKT-3          177              Bug  2023-10-13    2023-10-24
# 3      TCKT-4          169  Feature Request  2023-03-27    2023-04-07
# 4      TCKT-5           50          INVALID  2023-05-11           NaN
# ..        ...          ...              ...         ...           ...
# 795  TCKT-796           69          INVALID  2024-04-06    2024-04-19
# 796  TCKT-797           21      Login Issue  2023-06-28    2023-07-09
# 797  TCKT-798          126      Login Issue  2023-10-09    2023-10-19
# 798  TCKT-799          148  Feature Request  2023-09-25    2023-09-27
# 799  TCKT-800           85          INVALID  2023-07-04    2023-07-07
#
#      satisfaction_score
# 0                   4.0
# 1                   NaN
# 2                   NaN
# 3                   3.0
# 4                   5.0
# ..                  ...
# 795                 5.0
# 796                 NaN
# 797                 5.0
# 798                 5.0
# 799                 3.0
#
# [800 rows x 6 columns]

# %%
support_ticket_df.isna().sum()
# Out:
# ticket_id               0
# customer_id             0
# issue_type            109
# opened_date             0
# resolved_date         173
# satisfaction_score    175
# dtype: int64

# %%
support_ticket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ticket_id           800 non-null    object
#  1   customer_id         800 non-null    int64
#  2   issue_type          691 non-null    object
#  3   opened_date         800 non-null    object
#  4   resolved_date       627 non-null    object
#  5   satisfaction_score  625 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 37.6+ KB

# %%
support_ticket_df['opened_date'] = pd.to_datetime(support_ticket_df['opened_date'])
support_ticket_df['resolved_date'] = pd.to_datetime(support_ticket_df['resolved_date'])

# %%
support_ticket_df['issue_type'].unique()
# Out:
# array(['Feature Request', 'Login Issue', 'Bug', 'INVALID', 'Billing',
#        'Other', nan], dtype=object)

# %%
support_ticket_df['issue_type'].value_counts(dropna=False)
# Out:
# issue_type
# Login Issue        127
# Other              126
# Feature Request    115
# Bug                113
# NaN                109
# INVALID            108
# Billing            102
# Name: count, dtype: int64

# %% [markdown]
# ### Export cleaned dataframes to SQL tables

# %%
from sqlalchemy import create_engine

server = 'SHREY-GALAXYBOO'
database = 'churnDB'

connection_string = (
    f"mssql+pyodbc://{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

engine = create_engine(connection_string, echo=True)

# %%
customer_df.to_sql('customers', engine, schema = 'dbo', if_exists= 'replace', index = False)
product_df.to_sql('product_usage', engine, schema = 'dbo', if_exists = 'replace', index = False)
subscription_df.to_sql('subscription', engine, schema = 'dbo', if_exists = 'replace', index = False)
support_ticket_df.to_sql('support_tickets', engine, schema = 'dbo', if_exists = 'replace', index = False)
# Out:
# 2025-07-24 00:49:17,245 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2025-07-24 00:49:17,248 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-24 00:49:17,255 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2025-07-24 00:49:17,257 INFO sqlalchemy.engine.Engine [generated in 0.00246s] ()
# 2025-07-24 00:49:17,262 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2025-07-24 00:49:17,264 INFO sqlalchemy.engine.Engine [generated in 0.00214s] ()
# 2025-07-24 00:49:17,268 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2025-07-24 00:49:17,270 INFO sqlalchemy.engine.Engine [generated in 0.00226s] ()
# 2025-07-24 00:49:17,284 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 00:49:17,297 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,298 INFO sqlalchemy.engine.Engine [generated in 0.00232s] ('BASE TABLE', 'VIEW', 'customers', 'dbo')
# 2025-07-24 00:49:17,303 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,306 INFO sqlalchemy.engine.Engine [cached since 0.009482s ago] ('BASE TABLE', 'VIEW', 'customers', 'dbo')
# 2025-07-24 00:49:17,312 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# 2025-07-24 00:49:17,314 INFO sqlalchemy.engine.Engine [generated in 0.00202s] ('dbo', 'BASE TABLE')
# 2025-07-24 00:49:17,329 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# 2025-07-24 00:49:17,331 INFO sqlalchemy.engine.Engine [cached since 0.01964s ago] ('dbo', 'VIEW')
# 2025-07-24 00:49:17,354 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME], [INFORMATION_SCHEMA].[COLUMNS].[DATA_TYPE], [INFORMATION_SCHEMA].[COLUMNS].[IS_NULLABLE], [INFORMATION_SCHEMA].[COLUMNS].[CHARACTER_MAXIMUM_LENGTH], [INFORMATION_SCHEMA].[COLUMNS].[NUMERIC_PRECISION], [INFORMATION_SCHEMA].[COLUMNS].[NUMERIC_SCALE], [INFORMATION_SCHEMA].[COLUMNS].[COLUMN_DEFAULT], [INFORMATION_SCHEMA].[COLUMNS].[COLLATION_NAME], sys.computed_columns.definition, sys.computed_columns.is_persisted, sys.identity_columns.is_identity, CAST(sys.identity_columns.seed_value AS NUMERIC(38, 0)) AS seed_value, CAST(sys.identity_columns.increment_value AS NUMERIC(38, 0)) AS increment_value, CAST(sys.extended_properties.value AS NVARCHAR(max)) AS comment
# FROM [INFORMATION_SCHEMA].[COLUMNS] LEFT OUTER JOIN sys.computed_columns ON sys.computed_columns.object_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.computed_columns.name = ([INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME] COLLATE DATABASE_DEFAULT) LEFT OUTER JOIN sys.identity_columns ON sys.identity_columns.object_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.identity_columns.name = ([INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME] COLLATE DATABASE_DEFAULT) LEFT OUTER JOIN sys.extended_properties ON sys.extended_properties.class = ? AND sys.extended_properties.major_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.extended_properties.minor_id = [INFORMATION_SCHEMA].[COLUMNS].[ORDINAL_POSITION] AND sys.extended_properties.name = CAST(? AS NVARCHAR(max))
# WHERE [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[COLUMNS].[ORDINAL_POSITION]
# 2025-07-24 00:49:17,357 INFO sqlalchemy.engine.Engine [generated in 0.00364s] ('.', '.', 1, '.', 'MS_Description', 'customers', 'dbo')
# 2025-07-24 00:49:17,376 INFO sqlalchemy.engine.Engine SELECT [C].[COLUMN_NAME], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_TYPE], [C].[CONSTRAINT_NAME], objectproperty(object_id([C].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [C].[CONSTRAINT_NAME]), ?) AS is_clustered
# FROM [INFORMATION_SCHEMA].[KEY_COLUMN_USAGE] AS [C], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS]
# WHERE [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME] = [C].[CONSTRAINT_NAME] AND [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[TABLE_SCHEMA] = [C].[TABLE_SCHEMA] AND [C].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [C].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME], [C].[ORDINAL_POSITION]
# 2025-07-24 00:49:17,379 INFO sqlalchemy.engine.Engine [generated in 0.00263s] ('.', 'CnstIsClustKey', 'customers', 'dbo')
# 2025-07-24 00:49:17,385 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,388 INFO sqlalchemy.engine.Engine [cached since 0.09187s ago] ('BASE TABLE', 'VIEW', 'customers', 'dbo')
# 2025-07-24 00:49:17,394 INFO sqlalchemy.engine.Engine WITH fk_info AS (
#     SELECT
#         ischema_ref_con.constraint_schema,
#         ischema_ref_con.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_ref_con.unique_constraint_schema,
#         ischema_ref_con.unique_constraint_name,
#         ischema_ref_con.match_option,
#         ischema_ref_con.update_rule,
#         ischema_ref_con.delete_rule,
#         ischema_key_col.column_name AS constrained_column
#     FROM
#         INFORMATION_SCHEMA.REFERENTIAL_CONSTRAINTS ischema_ref_con
#         INNER JOIN
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col ON
#             ischema_key_col.table_schema = ischema_ref_con.constraint_schema
#             AND ischema_key_col.constraint_name =
#             ischema_ref_con.constraint_name
#     WHERE ischema_key_col.table_name = CAST(? AS NVARCHAR(max))
#         AND ischema_key_col.table_schema = CAST(? AS NVARCHAR(max))
# ),
# constraint_info AS (
#     SELECT
#         ischema_key_col.constraint_schema,
#         ischema_key_col.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_key_col.column_name
#     FROM
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col
# ),
# index_info AS (
#     SELECT
#         sys.schemas.name AS index_schema,
#         sys.indexes.name AS index_name,
#         sys.index_columns.key_ordinal AS ordinal_position,
#         sys.schemas.name AS table_schema,
#         sys.objects.name AS table_name,
#         sys.columns.name AS column_name
#     FROM
#         sys.indexes
#         INNER JOIN
#         sys.objects ON
#             sys.objects.object_id = sys.indexes.object_id
#         INNER JOIN
#         sys.schemas ON
#             sys.schemas.schema_id = sys.objects.schema_id
#         INNER JOIN
#         sys.index_columns ON
#             sys.index_columns.object_id = sys.objects.object_id
#             AND sys.index_columns.index_id = sys.indexes.index_id
#         INNER JOIN
#         sys.columns ON
#             sys.columns.object_id = sys.indexes.object_id
#             AND sys.columns.column_id = sys.index_columns.column_id
# )
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         constraint_info.table_schema AS referred_table_schema,
#         constraint_info.table_name AS referred_table_name,
#         constraint_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN constraint_info ON
#             constraint_info.constraint_schema =
#                 fk_info.unique_constraint_schema
#             AND constraint_info.constraint_name =
#                 fk_info.unique_constraint_name
#             AND constraint_info.ordinal_position = fk_info.ordinal_position
#     UNION
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         index_info.table_schema AS referred_table_schema,
#         index_info.table_name AS referred_table_name,
#         index_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN index_info ON
#             index_info.index_schema = fk_info.unique_constraint_schema
#             AND index_info.index_name = fk_info.unique_constraint_name
#             AND index_info.ordinal_position = fk_info.ordinal_position
#
#     ORDER BY fk_info.constraint_schema, fk_info.constraint_name,
#         fk_info.ordinal_position
#
# 2025-07-24 00:49:17,397 INFO sqlalchemy.engine.Engine [generated in 0.00279s] ('customers', 'dbo')
# 2025-07-24 00:49:17,410 INFO sqlalchemy.engine.Engine
# select
#     ind.index_id,
#     ind.is_unique,
#     ind.name,
#     ind.type,
#     ind.filter_definition
# from
#     sys.indexes as ind
# join sys.tables as tab on
#     ind.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#     and ind.is_primary_key = 0
#     and ind.type != 0
# order by
#     ind.name
#
# 2025-07-24 00:49:17,413 INFO sqlalchemy.engine.Engine [generated in 0.00331s] ('customers', 'dbo')
# 2025-07-24 00:49:17,418 INFO sqlalchemy.engine.Engine
# select
#     ind_col.index_id,
#     col.name,
#     ind_col.is_included_column
# from
#     sys.columns as col
# join sys.tables as tab on
#     tab.object_id = col.object_id
# join sys.index_columns as ind_col on
#     ind_col.column_id = col.column_id
#     and ind_col.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#
# 2025-07-24 00:49:17,422 INFO sqlalchemy.engine.Engine [generated in 0.00441s] ('customers', 'dbo')
# 2025-07-24 00:49:17,429 INFO sqlalchemy.engine.Engine
#             SELECT cast(com.value as nvarchar(max))
#             FROM fn_listextendedproperty('MS_Description',
#                 'schema', CAST(? AS NVARCHAR(max)), 'table', CAST(? AS NVARCHAR(max)), NULL, NULL
#             ) as com;
#
# 2025-07-24 00:49:17,431 INFO sqlalchemy.engine.Engine [generated in 0.00217s] ('dbo', 'customers')
# 2025-07-24 00:49:17,438 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,440 INFO sqlalchemy.engine.Engine [generated in 0.00315s] ('BASE TABLE', 'VIEW', 'customers')
# 2025-07-24 00:49:17,451 INFO sqlalchemy.engine.Engine
# DROP TABLE dbo.customers
# 2025-07-24 00:49:17,454 INFO sqlalchemy.engine.Engine [no key 0.00231s] ()
# 2025-07-24 00:49:17,466 INFO sqlalchemy.engine.Engine
# CREATE TABLE dbo.customers (
# 	customer_id BIGINT NULL,
# 	name VARCHAR(max) NULL,
# 	signup_date DATETIME NULL,
# 	industry VARCHAR(max) NULL,
# 	[plan] VARCHAR(max) NULL,
# 	location VARCHAR(max) NULL
# )
#
#
# 2025-07-24 00:49:17,468 INFO sqlalchemy.engine.Engine [no key 0.00279s] ()
# 2025-07-24 00:49:17,484 INFO sqlalchemy.engine.Engine INSERT INTO dbo.customers (customer_id, name, signup_date, industry, [plan], location) VALUES (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?,  ... 3742 characters truncated ... , (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?)
# 2025-07-24 00:49:17,487 INFO sqlalchemy.engine.Engine [generated in 0.00597s (insertmanyvalues) 1/1 (unordered)] (1, 'Customer_1', datetime.datetime(2023, 10, 17, 0, 0), 'Fintech', 'Basic', 'Unknown', 2, 'Customer_2', datetime.datetime(2022, 10, 9, 0, 0), 'E-commerce', 'Pro', 'San Francisco', 3, 'Customer_3', datetime.datetime(2022, 4, 15, 0, 0), 'Unknown', 'Basic', 'London', 4, 'Customer_4', datetime.datetime(2023, 3, 9, 0, 0), 'Fintech', 'Basic', 'New York', 5, 'Customer_5', datetime.datetime(2022, 8, 12, 0, 0), 'E-commerce', 'Basic', 'London', 6, 'Customer_6', datetime.datetime(2022, 7, 23, 0, 0), 'Unknown', 'Unknown', 'San Francisco', 7, 'Customer_7', datetime.datetime(2023, 4, 5, 0, 0), 'SaaS', 'Enterprise', 'New York', 8, 'Customer_8', datetime.datetime(2022, 6, 13, 0, 0), 'Unknown', 'Unknown', 'Bangalore', 9, 'Customer_9' ... 1100 parameters truncated ... 'Enterprise', 'Bangalore', 193, 'Customer_193', datetime.datetime(2022, 12, 15, 0, 0), 'Healthcare', 'Enterprise', 'London', 194, 'Customer_194', datetime.datetime(2022, 1, 11, 0, 0), 'SaaS', 'Pro', 'New York', 195, 'Customer_195', datetime.datetime(2022, 9, 5, 0, 0), 'Unknown', 'Unknown', 'Berlin', 196, 'Customer_196', datetime.datetime(2023, 7, 23, 0, 0), 'E-commerce', 'Unknown', 'Unknown', 197, 'Customer_197', datetime.datetime(2023, 12, 30, 0, 0), 'Education', 'Unknown', 'New York', 198, 'Customer_198', datetime.datetime(2022, 4, 6, 0, 0), 'Healthcare', 'Pro', 'Berlin', 199, 'Customer_199', datetime.datetime(2023, 12, 10, 0, 0), 'E-commerce', 'Enterprise', 'Unknown', 200, 'Customer_200', datetime.datetime(2023, 8, 19, 0, 0), 'Healthcare', 'Unknown', 'London')
# 2025-07-24 00:49:17,640 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-24 00:49:17,649 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 00:49:17,655 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,656 INFO sqlalchemy.engine.Engine [cached since 0.3605s ago] ('BASE TABLE', 'VIEW', 'product_usage', 'dbo')
# 2025-07-24 00:49:17,663 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,665 INFO sqlalchemy.engine.Engine [cached since 0.3692s ago] ('BASE TABLE', 'VIEW', 'product_usage', 'dbo')
# 2025-07-24 00:49:17,670 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# 2025-07-24 00:49:17,671 INFO sqlalchemy.engine.Engine [cached since 0.3599s ago] ('dbo', 'BASE TABLE')
# 2025-07-24 00:49:17,684 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# 2025-07-24 00:49:17,687 INFO sqlalchemy.engine.Engine [cached since 0.376s ago] ('dbo', 'VIEW')
# 2025-07-24 00:49:17,702 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME], [INFORMATION_SCHEMA].[COLUMNS].[DATA_TYPE], [INFORMATION_SCHEMA].[COLUMNS].[IS_NULLABLE], [INFORMATION_SCHEMA].[COLUMNS].[CHARACTER_MAXIMUM_LENGTH], [INFORMATION_SCHEMA].[COLUMNS].[NUMERIC_PRECISION], [INFORMATION_SCHEMA].[COLUMNS].[NUMERIC_SCALE], [INFORMATION_SCHEMA].[COLUMNS].[COLUMN_DEFAULT], [INFORMATION_SCHEMA].[COLUMNS].[COLLATION_NAME], sys.computed_columns.definition, sys.computed_columns.is_persisted, sys.identity_columns.is_identity, CAST(sys.identity_columns.seed_value AS NUMERIC(38, 0)) AS seed_value, CAST(sys.identity_columns.increment_value AS NUMERIC(38, 0)) AS increment_value, CAST(sys.extended_properties.value AS NVARCHAR(max)) AS comment
# FROM [INFORMATION_SCHEMA].[COLUMNS] LEFT OUTER JOIN sys.computed_columns ON sys.computed_columns.object_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.computed_columns.name = ([INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME] COLLATE DATABASE_DEFAULT) LEFT OUTER JOIN sys.identity_columns ON sys.identity_columns.object_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.identity_columns.name = ([INFORMATION_SCHEMA].[COLUMNS].[COLUMN_NAME] COLLATE DATABASE_DEFAULT) LEFT OUTER JOIN sys.extended_properties ON sys.extended_properties.class = ? AND sys.extended_properties.major_id = object_id([INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME]) AND sys.extended_properties.minor_id = [INFORMATION_SCHEMA].[COLUMNS].[ORDINAL_POSITION] AND sys.extended_properties.name = CAST(? AS NVARCHAR(max))
# WHERE [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[COLUMNS].[ORDINAL_POSITION]
# 2025-07-24 00:49:17,705 INFO sqlalchemy.engine.Engine [cached since 0.3521s ago] ('.', '.', 1, '.', 'MS_Description', 'product_usage', 'dbo')
# 2025-07-24 00:49:17,717 INFO sqlalchemy.engine.Engine SELECT [C].[COLUMN_NAME], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_TYPE], [C].[CONSTRAINT_NAME], objectproperty(object_id([C].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [C].[CONSTRAINT_NAME]), ?) AS is_clustered
# FROM [INFORMATION_SCHEMA].[KEY_COLUMN_USAGE] AS [C], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS]
# WHERE [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME] = [C].[CONSTRAINT_NAME] AND [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[TABLE_SCHEMA] = [C].[TABLE_SCHEMA] AND [C].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [C].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME], [C].[ORDINAL_POSITION]
# 2025-07-24 00:49:17,719 INFO sqlalchemy.engine.Engine [cached since 0.3429s ago] ('.', 'CnstIsClustKey', 'product_usage', 'dbo')
# 2025-07-24 00:49:17,724 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,727 INFO sqlalchemy.engine.Engine [cached since 0.4308s ago] ('BASE TABLE', 'VIEW', 'product_usage', 'dbo')
# 2025-07-24 00:49:17,734 INFO sqlalchemy.engine.Engine WITH fk_info AS (
#     SELECT
#         ischema_ref_con.constraint_schema,
#         ischema_ref_con.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_ref_con.unique_constraint_schema,
#         ischema_ref_con.unique_constraint_name,
#         ischema_ref_con.match_option,
#         ischema_ref_con.update_rule,
#         ischema_ref_con.delete_rule,
#         ischema_key_col.column_name AS constrained_column
#     FROM
#         INFORMATION_SCHEMA.REFERENTIAL_CONSTRAINTS ischema_ref_con
#         INNER JOIN
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col ON
#             ischema_key_col.table_schema = ischema_ref_con.constraint_schema
#             AND ischema_key_col.constraint_name =
#             ischema_ref_con.constraint_name
#     WHERE ischema_key_col.table_name = CAST(? AS NVARCHAR(max))
#         AND ischema_key_col.table_schema = CAST(? AS NVARCHAR(max))
# ),
# constraint_info AS (
#     SELECT
#         ischema_key_col.constraint_schema,
#         ischema_key_col.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_key_col.column_name
#     FROM
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col
# ),
# index_info AS (
#     SELECT
#         sys.schemas.name AS index_schema,
#         sys.indexes.name AS index_name,
#         sys.index_columns.key_ordinal AS ordinal_position,
#         sys.schemas.name AS table_schema,
#         sys.objects.name AS table_name,
#         sys.columns.name AS column_name
#     FROM
#         sys.indexes
#         INNER JOIN
#         sys.objects ON
#             sys.objects.object_id = sys.indexes.object_id
#         INNER JOIN
#         sys.schemas ON
#             sys.schemas.schema_id = sys.objects.schema_id
#         INNER JOIN
#         sys.index_columns ON
#             sys.index_columns.object_id = sys.objects.object_id
#             AND sys.index_columns.index_id = sys.indexes.index_id
#         INNER JOIN
#         sys.columns ON
#             sys.columns.object_id = sys.indexes.object_id
#             AND sys.columns.column_id = sys.index_columns.column_id
# )
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         constraint_info.table_schema AS referred_table_schema,
#         constraint_info.table_name AS referred_table_name,
#         constraint_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN constraint_info ON
#             constraint_info.constraint_schema =
#                 fk_info.unique_constraint_schema
#             AND constraint_info.constraint_name =
#                 fk_info.unique_constraint_name
#             AND constraint_info.ordinal_position = fk_info.ordinal_position
#     UNION
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         index_info.table_schema AS referred_table_schema,
#         index_info.table_name AS referred_table_name,
#         index_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN index_info ON
#             index_info.index_schema = fk_info.unique_constraint_schema
#             AND index_info.index_name = fk_info.unique_constraint_name
#             AND index_info.ordinal_position = fk_info.ordinal_position
#
#     ORDER BY fk_info.constraint_schema, fk_info.constraint_name,
#         fk_info.ordinal_position
#
# 2025-07-24 00:49:17,737 INFO sqlalchemy.engine.Engine [cached since 0.3431s ago] ('product_usage', 'dbo')
# 2025-07-24 00:49:17,749 INFO sqlalchemy.engine.Engine
# select
#     ind.index_id,
#     ind.is_unique,
#     ind.name,
#     ind.type,
#     ind.filter_definition
# from
#     sys.indexes as ind
# join sys.tables as tab on
#     ind.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#     and ind.is_primary_key = 0
#     and ind.type != 0
# order by
#     ind.name
#
# 2025-07-24 00:49:17,751 INFO sqlalchemy.engine.Engine [cached since 0.3419s ago] ('product_usage', 'dbo')
# 2025-07-24 00:49:17,756 INFO sqlalchemy.engine.Engine
# select
#     ind_col.index_id,
#     col.name,
#     ind_col.is_included_column
# from
#     sys.columns as col
# join sys.tables as tab on
#     tab.object_id = col.object_id
# join sys.index_columns as ind_col on
#     ind_col.column_id = col.column_id
#     and ind_col.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#
# 2025-07-24 00:49:17,757 INFO sqlalchemy.engine.Engine [cached since 0.3399s ago] ('product_usage', 'dbo')
# 2025-07-24 00:49:17,761 INFO sqlalchemy.engine.Engine
#             SELECT cast(com.value as nvarchar(max))
#             FROM fn_listextendedproperty('MS_Description',
#                 'schema', CAST(? AS NVARCHAR(max)), 'table', CAST(? AS NVARCHAR(max)), NULL, NULL
#             ) as com;
#
# 2025-07-24 00:49:17,763 INFO sqlalchemy.engine.Engine [cached since 0.3341s ago] ('dbo', 'product_usage')
# 2025-07-24 00:49:17,769 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:17,772 INFO sqlalchemy.engine.Engine [cached since 0.3348s ago] ('BASE TABLE', 'VIEW', 'product_usage')
# 2025-07-24 00:49:17,776 INFO sqlalchemy.engine.Engine
# DROP TABLE dbo.product_usage
# 2025-07-24 00:49:17,778 INFO sqlalchemy.engine.Engine [no key 0.00228s] ()
# 2025-07-24 00:49:17,786 INFO sqlalchemy.engine.Engine
# CREATE TABLE dbo.product_usage (
# 	customer_id BIGINT NULL,
# 	usage_date DATETIME NULL,
# 	features_used VARCHAR(max) NULL,
# 	minutes_spent FLOAT(53) NULL,
# 	errors_reported FLOAT(53) NULL
# )
#
#
# 2025-07-24 00:49:17,789 INFO sqlalchemy.engine.Engine [no key 0.00304s] ()
# 2025-07-24 00:49:17,857 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:17,860 INFO sqlalchemy.engine.Engine [generated in 0.03115s (insertmanyvalues) 1/12 (unordered)] (34, datetime.datetime(2024, 3, 31, 0, 0), 'Upload', 59.9, 1.0, 97, datetime.datetime(2024, 4, 25, 0, 0), 'Reports', 40.85, 0.0, 190, datetime.datetime(2024, 5, 16, 0, 0), 'Export', 53.37, 1.0, 131, datetime.datetime(2023, 12, 3, 0, 0), 'Dashboard', 75.32, 2.0, 55, datetime.datetime(2023, 11, 22, 0, 0), 'Alerts', 31.1, 0.0, 40, datetime.datetime(2023, 7, 10, 0, 0), 'Reports', 31.03, 0.0, 198, datetime.datetime(2024, 3, 3, 0, 0), 'Upload', 6.75, None, 87, datetime.datetime(2024, 6, 27, 0, 0), 'Export', 28.13, 1.0, 42, datetime.datetime(2023, 9, 1, 0, 0), 'Upload', 17.76, 0.0, 43, datetime.datetime(2024, 6, 4, 0, 0), 'Alerts', 2.63, 1.0 ... 1995 parameters truncated ... 24, datetime.datetime(2023, 6, 29, 0, 0), 'API', 56.47, None, 123, datetime.datetime(2023, 6, 1, 0, 0), 'Reports', 49.99, 1.0, 34, datetime.datetime(2023, 11, 22, 0, 0), 'Upload', 59.77, 0.0, 83, datetime.datetime(2023, 7, 1, 0, 0), 'Dashboard', 29.47, 0.0, 37, datetime.datetime(2023, 7, 27, 0, 0), 'Export', 27.03, 1.0, 96, datetime.datetime(2024, 5, 26, 0, 0), 'Upload', 87.62, 1.0, 78, datetime.datetime(2023, 11, 13, 0, 0), 'API', 27.88, 1.0, 112, datetime.datetime(2024, 4, 23, 0, 0), 'Alerts', 51.09, 0.0, 144, datetime.datetime(2024, 5, 21, 0, 0), 'Export', 0.47, 0.0, 151, datetime.datetime(2023, 8, 29, 0, 0), 'Alerts', 26.62, 3.0)
# 2025-07-24 00:49:18,223 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:18,225 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/12 (unordered)] (33, datetime.datetime(2023, 8, 30, 0, 0), 'Upload', 33.37, 1.0, 147, datetime.datetime(2023, 12, 18, 0, 0), 'Export', 39.69, 0.0, 157, datetime.datetime(2023, 9, 22, 0, 0), 'Upload', 21.05, 0.0, 37, datetime.datetime(2023, 11, 17, 0, 0), 'Upload', 44.01, 0.0, 82, datetime.datetime(2023, 8, 25, 0, 0), 'Upload', 98.84, None, 182, datetime.datetime(2024, 5, 9, 0, 0), 'Upload', 65.84, 0.0, 3, datetime.datetime(2023, 10, 14, 0, 0), 'API', 13.18, None, 66, datetime.datetime(2023, 7, 26, 0, 0), 'Upload', 44.51, 0.0, 188, datetime.datetime(2024, 1, 1, 0, 0), 'API', 80.65, 0.0, 97, datetime.datetime(2023, 11, 27, 0, 0), 'Export', 30.32, 1.0 ... 1995 parameters truncated ... 47, datetime.datetime(2024, 3, 8, 0, 0), 'Alerts', 22.99, 1.0, 137, datetime.datetime(2024, 4, 3, 0, 0), 'Alerts', 46.08, 0.0, 141, datetime.datetime(2023, 11, 14, 0, 0), 'Reports', 74.26, 1.0, 186, datetime.datetime(2023, 11, 13, 0, 0), 'Export', 60.03, 0.0, 97, datetime.datetime(2024, 6, 27, 0, 0), 'Export', 9.3, 0.0, 116, datetime.datetime(2024, 1, 16, 0, 0), 'Alerts', 24.36, None, 73, datetime.datetime(2024, 4, 1, 0, 0), 'Dashboard', 60.34, 1.0, 78, datetime.datetime(2023, 6, 4, 0, 0), 'Reports', 86.21, 1.0, 81, datetime.datetime(2023, 6, 12, 0, 0), 'Upload', 94.2, 0.0, 131, datetime.datetime(2024, 3, 11, 0, 0), 'Export', 67.26, 0.0)
# 2025-07-24 00:49:18,426 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:18,430 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/12 (unordered)] (10, datetime.datetime(2024, 1, 22, 0, 0), 'Reports', 37.62, 0.0, 150, datetime.datetime(2023, 10, 6, 0, 0), 'API', 19.7, 2.0, 147, datetime.datetime(2023, 12, 22, 0, 0), 'Export', 46.31, 1.0, 186, datetime.datetime(2023, 11, 14, 0, 0), 'Alerts', 95.85, 0.0, 177, datetime.datetime(2024, 5, 25, 0, 0), 'Export', 31.81, None, 165, datetime.datetime(2023, 11, 1, 0, 0), 'Dashboard', 21.23, 0.0, 21, datetime.datetime(2023, 6, 29, 0, 0), 'Reports', 32.12, 1.0, 107, datetime.datetime(2023, 8, 1, 0, 0), 'API', 24.23, 0.0, 3, datetime.datetime(2024, 4, 20, 0, 0), 'Upload', 58.56, 0.0, 11, datetime.datetime(2023, 11, 11, 0, 0), 'Export', 7.8, 0.0 ... 1995 parameters truncated ... 31, datetime.datetime(2023, 12, 14, 0, 0), 'Alerts', 54.32, 1.0, 118, datetime.datetime(2023, 6, 19, 0, 0), 'Dashboard', 99.28, 0.0, 200, datetime.datetime(2023, 11, 3, 0, 0), 'Upload', 38.46, 0.0, 80, datetime.datetime(2024, 6, 1, 0, 0), 'Alerts', 12.31, 0.0, 173, datetime.datetime(2024, 2, 7, 0, 0), 'Upload', 21.46, 0.0, 121, datetime.datetime(2024, 1, 30, 0, 0), 'Export', 45.47, 0.0, 101, datetime.datetime(2023, 10, 13, 0, 0), 'Alerts', 72.07, 0.0, 174, datetime.datetime(2023, 11, 28, 0, 0), 'Reports', 17.77, None, 12, datetime.datetime(2023, 8, 5, 0, 0), 'Reports', 90.58, 1.0, 7, datetime.datetime(2024, 6, 26, 0, 0), 'Upload', 25.26, None)
# 2025-07-24 00:49:18,598 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:18,600 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/12 (unordered)] (89, datetime.datetime(2023, 11, 30, 0, 0), 'Alerts', 70.64, 1.0, 64, datetime.datetime(2023, 9, 29, 0, 0), 'Upload', 50.16, None, 177, datetime.datetime(2023, 7, 4, 0, 0), 'Reports', 61.6, 0.0, 138, datetime.datetime(2023, 11, 14, 0, 0), 'Dashboard', 20.48, 1.0, 146, datetime.datetime(2024, 2, 19, 0, 0), 'Alerts', 26.71, 0.0, 151, datetime.datetime(2023, 6, 12, 0, 0), 'Reports', 70.45, 2.0, 147, datetime.datetime(2023, 7, 21, 0, 0), 'Alerts', 8.02, 0.0, 87, datetime.datetime(2024, 2, 10, 0, 0), 'Export', 52.81, 0.0, 43, datetime.datetime(2024, 4, 10, 0, 0), 'Reports', 28.83, 0.0, 128, datetime.datetime(2024, 4, 21, 0, 0), 'Dashboard', 55.49, 0.0 ... 1995 parameters truncated ... 98, datetime.datetime(2024, 2, 22, 0, 0), 'Reports', 80.42, 1.0, 17, datetime.datetime(2024, 2, 7, 0, 0), 'Dashboard', 26.18, None, 37, datetime.datetime(2023, 9, 13, 0, 0), 'API', 46.36, 0.0, 53, datetime.datetime(2023, 9, 29, 0, 0), 'Export', 46.54, 0.0, 80, datetime.datetime(2023, 8, 24, 0, 0), 'Upload', 54.69, 0.0, 156, datetime.datetime(2023, 10, 6, 0, 0), 'Reports', 43.17, 1.0, 163, datetime.datetime(2023, 9, 12, 0, 0), 'Reports', 28.38, 0.0, 93, datetime.datetime(2023, 12, 21, 0, 0), 'Alerts', 92.97, 2.0, 130, datetime.datetime(2024, 4, 8, 0, 0), 'Upload', 49.79, 0.0, 124, datetime.datetime(2023, 6, 11, 0, 0), 'Alerts', 34.01, None)
# 2025-07-24 00:49:18,773 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:18,774 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/12 (unordered)] (77, datetime.datetime(2024, 3, 31, 0, 0), 'Export', 83.39, 0.0, 66, datetime.datetime(2023, 12, 12, 0, 0), 'Alerts', 21.5, 0.0, 144, datetime.datetime(2024, 4, 6, 0, 0), 'Alerts', 16.03, 0.0, 121, datetime.datetime(2023, 9, 9, 0, 0), 'API', 93.87, None, 129, datetime.datetime(2024, 6, 8, 0, 0), 'Upload', 86.04, 0.0, 107, datetime.datetime(2023, 12, 20, 0, 0), 'Upload', 9.94, 0.0, 165, datetime.datetime(2024, 3, 28, 0, 0), 'Dashboard', 79.28, None, 32, datetime.datetime(2023, 12, 15, 0, 0), 'Export', 6.98, 0.0, 66, datetime.datetime(2024, 6, 29, 0, 0), 'Upload', 41.9, 0.0, 163, datetime.datetime(2024, 5, 18, 0, 0), 'Reports', 7.83, 0.0 ... 1995 parameters truncated ... 54, datetime.datetime(2024, 3, 29, 0, 0), 'Export', 46.42, 0.0, 80, datetime.datetime(2024, 5, 28, 0, 0), 'Alerts', 57.13, 0.0, 28, datetime.datetime(2023, 8, 6, 0, 0), 'API', 66.48, 2.0, 116, datetime.datetime(2024, 4, 13, 0, 0), 'Export', 54.22, 1.0, 18, datetime.datetime(2023, 10, 21, 0, 0), 'Alerts', 20.26, 1.0, 148, datetime.datetime(2024, 4, 27, 0, 0), 'Dashboard', 29.23, 1.0, 191, datetime.datetime(2023, 7, 27, 0, 0), 'API', 45.97, 0.0, 69, datetime.datetime(2023, 6, 15, 0, 0), 'Alerts', 56.89, 0.0, 68, datetime.datetime(2023, 7, 31, 0, 0), 'Export', 9.25, 1.0, 39, datetime.datetime(2023, 12, 21, 0, 0), 'Export', 26.15, 0.0)
# 2025-07-24 00:49:18,952 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:18,954 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/12 (unordered)] (113, datetime.datetime(2023, 10, 18, 0, 0), 'Reports', 106.26, 1.0, 188, datetime.datetime(2024, 1, 3, 0, 0), 'API', 57.77, 0.0, 153, datetime.datetime(2023, 10, 20, 0, 0), 'Export', 78.24, 0.0, 28, datetime.datetime(2024, 5, 14, 0, 0), 'Dashboard', 32.81, 0.0, 57, datetime.datetime(2023, 7, 29, 0, 0), 'Dashboard', 26.5, 1.0, 62, datetime.datetime(2023, 7, 4, 0, 0), 'Export', 60.45, 0.0, 159, datetime.datetime(2024, 5, 24, 0, 0), 'Upload', 69.6, 1.0, 57, datetime.datetime(2024, 6, 10, 0, 0), 'Upload', 3.09, 1.0, 53, datetime.datetime(2023, 11, 25, 0, 0), 'Upload', 81.66, 0.0, 188, datetime.datetime(2023, 6, 2, 0, 0), 'Dashboard', 77.4, 3.0 ... 1995 parameters truncated ... 191, datetime.datetime(2024, 2, 11, 0, 0), 'API', 35.08, 1.0, 100, datetime.datetime(2023, 10, 9, 0, 0), 'Alerts', 29.7, 0.0, 21, datetime.datetime(2024, 4, 19, 0, 0), 'Alerts', 6.27, 1.0, 54, datetime.datetime(2024, 6, 17, 0, 0), 'Export', 81.89, 0.0, 81, datetime.datetime(2024, 1, 18, 0, 0), 'Upload', 48.22, 1.0, 150, datetime.datetime(2023, 8, 25, 0, 0), 'Export', 12.64, 2.0, 196, datetime.datetime(2023, 6, 12, 0, 0), 'Reports', 19.67, 0.0, 61, datetime.datetime(2023, 12, 10, 0, 0), 'Export', 64.27, 0.0, 32, datetime.datetime(2023, 7, 20, 0, 0), 'Alerts', 27.77, 0.0, 147, datetime.datetime(2023, 10, 27, 0, 0), 'API', 55.05, 0.0)
# 2025-07-24 00:49:19,138 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:19,140 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/12 (unordered)] (189, datetime.datetime(2023, 12, 23, 0, 0), 'Export', 84.62, 0.0, 108, datetime.datetime(2024, 4, 2, 0, 0), 'Reports', 50.08, 1.0, 28, datetime.datetime(2024, 5, 6, 0, 0), 'Upload', 99.23, 0.0, 82, datetime.datetime(2024, 2, 13, 0, 0), 'Export', 60.18, 0.0, 104, datetime.datetime(2024, 2, 9, 0, 0), 'Alerts', 54.23, 1.0, 41, datetime.datetime(2023, 8, 30, 0, 0), 'Alerts', 107.05, 1.0, 86, datetime.datetime(2024, 6, 25, 0, 0), 'Alerts', 41.94, 1.0, 26, datetime.datetime(2023, 12, 14, 0, 0), 'Export', 19.73, 0.0, 106, datetime.datetime(2023, 9, 5, 0, 0), 'Upload', 35.99, 0.0, 157, datetime.datetime(2024, 4, 13, 0, 0), 'Export', 60.31, 2.0 ... 1995 parameters truncated ... 128, datetime.datetime(2024, 1, 8, 0, 0), 'Alerts', 59.42, 0.0, 171, datetime.datetime(2023, 7, 1, 0, 0), 'Reports', 46.48, None, 83, datetime.datetime(2024, 5, 27, 0, 0), 'Alerts', 66.67, 1.0, 133, datetime.datetime(2024, 2, 9, 0, 0), 'API', 50.4, None, 79, datetime.datetime(2024, 4, 19, 0, 0), 'API', 36.81, 1.0, 159, datetime.datetime(2024, 1, 6, 0, 0), 'Export', 71.02, 0.0, 73, datetime.datetime(2023, 11, 22, 0, 0), 'Upload', 30.08, 1.0, 33, datetime.datetime(2023, 12, 7, 0, 0), 'Export', 64.88, None, 115, datetime.datetime(2023, 12, 7, 0, 0), 'Alerts', 49.24, 1.0, 177, datetime.datetime(2023, 9, 28, 0, 0), 'Reports', 12.84, 0.0)
# 2025-07-24 00:49:19,307 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:19,309 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/12 (unordered)] (122, datetime.datetime(2023, 10, 22, 0, 0), 'Export', 84.07, 2.0, 179, datetime.datetime(2023, 9, 8, 0, 0), 'API', 31.67, 0.0, 147, datetime.datetime(2023, 9, 26, 0, 0), 'Upload', 40.72, 0.0, 64, datetime.datetime(2024, 2, 6, 0, 0), 'Export', 51.76, None, 131, datetime.datetime(2023, 7, 19, 0, 0), 'Alerts', 92.37, 1.0, 21, datetime.datetime(2024, 2, 26, 0, 0), 'Alerts', 6.09, 0.0, 187, datetime.datetime(2023, 10, 15, 0, 0), 'Dashboard', 25.28, 0.0, 198, datetime.datetime(2023, 10, 20, 0, 0), 'Upload', 40.93, 1.0, 16, datetime.datetime(2024, 1, 29, 0, 0), 'API', 68.17, None, 92, datetime.datetime(2024, 4, 13, 0, 0), 'Alerts', 56.95, 0.0 ... 1995 parameters truncated ... 43, datetime.datetime(2024, 5, 2, 0, 0), 'Upload', 18.3, 1.0, 126, datetime.datetime(2023, 9, 19, 0, 0), 'Alerts', 85.18, 1.0, 129, datetime.datetime(2024, 3, 25, 0, 0), 'API', 24.4, 0.0, 110, datetime.datetime(2024, 5, 22, 0, 0), 'Reports', 79.9, 1.0, 143, datetime.datetime(2024, 5, 22, 0, 0), 'API', 68.9, None, 161, datetime.datetime(2024, 3, 19, 0, 0), 'Dashboard', 102.15, 0.0, 41, datetime.datetime(2023, 9, 28, 0, 0), 'Upload', 97.53, 0.0, 54, datetime.datetime(2023, 9, 10, 0, 0), 'API', 44.05, None, 116, datetime.datetime(2023, 9, 24, 0, 0), 'Export', 66.44, 0.0, 186, datetime.datetime(2023, 9, 13, 0, 0), 'Reports', 54.11, 0.0)
# 2025-07-24 00:49:19,473 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:19,475 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/12 (unordered)] (77, datetime.datetime(2024, 5, 17, 0, 0), 'Alerts', 30.11, None, 41, datetime.datetime(2024, 1, 29, 0, 0), 'Alerts', 96.42, 0.0, 137, datetime.datetime(2023, 8, 29, 0, 0), 'Upload', 45.63, 0.0, 22, datetime.datetime(2024, 6, 26, 0, 0), 'API', 11.07, 0.0, 28, datetime.datetime(2024, 1, 9, 0, 0), 'API', 21.53, 0.0, 183, datetime.datetime(2024, 2, 22, 0, 0), 'Upload', 70.59, 2.0, 152, datetime.datetime(2024, 3, 26, 0, 0), 'Reports', 88.4, 0.0, 153, datetime.datetime(2024, 2, 28, 0, 0), 'Upload', 31.2, 0.0, 109, datetime.datetime(2023, 8, 28, 0, 0), 'Export', 32.11, 1.0, 81, datetime.datetime(2023, 10, 12, 0, 0), 'Export', 5.97, 1.0 ... 1995 parameters truncated ... 172, datetime.datetime(2024, 1, 31, 0, 0), 'Upload', 78.83, 0.0, 151, datetime.datetime(2023, 11, 29, 0, 0), 'API', 17.25, 1.0, 23, datetime.datetime(2024, 3, 24, 0, 0), 'Alerts', 31.49, 2.0, 127, datetime.datetime(2024, 3, 9, 0, 0), 'Upload', 28.52, 0.0, 173, datetime.datetime(2024, 5, 19, 0, 0), 'Export', 19.94, 0.0, 97, datetime.datetime(2023, 11, 29, 0, 0), 'Dashboard', 58.56, 0.0, 169, datetime.datetime(2024, 5, 9, 0, 0), 'Upload', 5.29, 0.0, 12, datetime.datetime(2024, 4, 5, 0, 0), 'Alerts', 87.61, 0.0, 157, datetime.datetime(2023, 12, 10, 0, 0), 'Alerts', 20.33, 0.0, 157, datetime.datetime(2024, 1, 6, 0, 0), 'Dashboard', 14.19, 1.0)
# 2025-07-24 00:49:19,648 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:19,650 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/12 (unordered)] (39, datetime.datetime(2023, 7, 4, 0, 0), 'Alerts', 73.93, 1.0, 27, datetime.datetime(2023, 12, 15, 0, 0), 'API', 29.32, 0.0, 149, datetime.datetime(2024, 6, 24, 0, 0), 'API', 60.08, 1.0, 139, datetime.datetime(2024, 3, 6, 0, 0), 'API', 62.97, 1.0, 200, datetime.datetime(2023, 9, 22, 0, 0), 'Reports', 70.6, 1.0, 129, datetime.datetime(2023, 9, 25, 0, 0), 'Export', 43.24, 0.0, 67, datetime.datetime(2023, 12, 20, 0, 0), 'Alerts', 38.37, 0.0, 135, datetime.datetime(2024, 1, 14, 0, 0), 'Export', 39.19, 1.0, 160, datetime.datetime(2023, 7, 3, 0, 0), 'Dashboard', 67.34, 0.0, 29, datetime.datetime(2024, 3, 27, 0, 0), 'Upload', 15.0, 1.0 ... 1995 parameters truncated ... 144, datetime.datetime(2024, 1, 24, 0, 0), 'Alerts', 98.35, 0.0, 196, datetime.datetime(2024, 1, 9, 0, 0), 'Alerts', 64.2, 1.0, 152, datetime.datetime(2024, 1, 17, 0, 0), 'Reports', 15.54, None, 52, datetime.datetime(2023, 12, 15, 0, 0), 'Reports', 24.4, 0.0, 66, datetime.datetime(2023, 11, 17, 0, 0), 'Dashboard', 79.39, 1.0, 81, datetime.datetime(2024, 5, 23, 0, 0), 'API', 83.21, None, 190, datetime.datetime(2023, 12, 15, 0, 0), 'Reports', 77.74, 0.0, 119, datetime.datetime(2024, 1, 12, 0, 0), 'Dashboard', 43.26, 2.0, 167, datetime.datetime(2023, 12, 1, 0, 0), 'API', 83.25, 0.0, 83, datetime.datetime(2023, 9, 14, 0, 0), 'Dashboard', 119.22, 0.0)
# 2025-07-24 00:49:19,824 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6881 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# 2025-07-24 00:49:19,825 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/12 (unordered)] (185, datetime.datetime(2023, 6, 5, 0, 0), 'API', 35.15, 2.0, 136, datetime.datetime(2023, 8, 22, 0, 0), 'Alerts', 40.92, 1.0, 77, datetime.datetime(2023, 9, 29, 0, 0), 'Dashboard', 106.12, 1.0, 135, datetime.datetime(2024, 4, 13, 0, 0), 'Export', 49.41, 2.0, 157, datetime.datetime(2023, 12, 19, 0, 0), 'Reports', 40.2, 2.0, 112, datetime.datetime(2023, 10, 5, 0, 0), 'Reports', 65.28, 1.0, 75, datetime.datetime(2024, 6, 16, 0, 0), 'API', 115.37, 0.0, 19, datetime.datetime(2023, 11, 4, 0, 0), 'Export', 3.0, 0.0, 155, datetime.datetime(2024, 3, 28, 0, 0), 'API', 92.76, 2.0, 181, datetime.datetime(2023, 10, 11, 0, 0), 'Reports', 27.37, 0.0 ... 1995 parameters truncated ... 92, datetime.datetime(2024, 4, 22, 0, 0), 'API', 27.09, 2.0, 57, datetime.datetime(2023, 11, 24, 0, 0), 'Alerts', 6.31, 0.0, 41, datetime.datetime(2024, 4, 13, 0, 0), 'Dashboard', 35.95, 1.0, 36, datetime.datetime(2024, 3, 9, 0, 0), 'Upload', 43.45, 2.0, 176, datetime.datetime(2024, 1, 1, 0, 0), 'Dashboard', 20.73, 0.0, 84, datetime.datetime(2023, 11, 25, 0, 0), 'Export', 112.3, 1.0, 102, datetime.datetime(2023, 7, 29, 0, 0), 'Dashboard', 12.3, 1.0, 57, datetime.datetime(2023, 6, 29, 0, 0), 'Reports', 113.41, None, 22, datetime.datetime(2023, 8, 5, 0, 0), 'Export', 22.99, 0.0, 23, datetime.datetime(2023, 6, 16, 0, 0), 'Dashboard', 27.76, 0.0)
# 2025-07-24 00:49:19,988 INFO sqlalchemy.engine.Engine INSERT INTO dbo.product_usage (customer_id, usage_date, features_used, minutes_spent, errors_reported) VALUES (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?,  ... 6405 characters truncated ... (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?), (?, ?, ?, ?, ?)
# ...
# WHERE [INFORMATION_SCHEMA].[COLUMNS].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[COLUMNS].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[COLUMNS].[ORDINAL_POSITION]
# 2025-07-24 00:49:20,470 INFO sqlalchemy.engine.Engine [cached since 3.116s ago] ('.', '.', 1, '.', 'MS_Description', 'support_tickets', 'dbo')
# 2025-07-24 00:49:20,475 INFO sqlalchemy.engine.Engine SELECT [C].[COLUMN_NAME], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_TYPE], [C].[CONSTRAINT_NAME], objectproperty(object_id([C].[TABLE_SCHEMA] + CAST(? AS NVARCHAR(max)) + [C].[CONSTRAINT_NAME]), ?) AS is_clustered
# FROM [INFORMATION_SCHEMA].[KEY_COLUMN_USAGE] AS [C], [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS]
# WHERE [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME] = [C].[CONSTRAINT_NAME] AND [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[TABLE_SCHEMA] = [C].[TABLE_SCHEMA] AND [C].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [C].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max)) ORDER BY [INFORMATION_SCHEMA].[TABLE_CONSTRAINTS].[CONSTRAINT_NAME], [C].[ORDINAL_POSITION]
# 2025-07-24 00:49:20,476 INFO sqlalchemy.engine.Engine [cached since 3.1s ago] ('.', 'CnstIsClustKey', 'support_tickets', 'dbo')
# 2025-07-24 00:49:20,480 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:20,481 INFO sqlalchemy.engine.Engine [cached since 3.185s ago] ('BASE TABLE', 'VIEW', 'support_tickets', 'dbo')
# 2025-07-24 00:49:20,484 INFO sqlalchemy.engine.Engine WITH fk_info AS (
#     SELECT
#         ischema_ref_con.constraint_schema,
#         ischema_ref_con.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_ref_con.unique_constraint_schema,
#         ischema_ref_con.unique_constraint_name,
#         ischema_ref_con.match_option,
#         ischema_ref_con.update_rule,
#         ischema_ref_con.delete_rule,
#         ischema_key_col.column_name AS constrained_column
#     FROM
#         INFORMATION_SCHEMA.REFERENTIAL_CONSTRAINTS ischema_ref_con
#         INNER JOIN
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col ON
#             ischema_key_col.table_schema = ischema_ref_con.constraint_schema
#             AND ischema_key_col.constraint_name =
#             ischema_ref_con.constraint_name
#     WHERE ischema_key_col.table_name = CAST(? AS NVARCHAR(max))
#         AND ischema_key_col.table_schema = CAST(? AS NVARCHAR(max))
# ),
# constraint_info AS (
#     SELECT
#         ischema_key_col.constraint_schema,
#         ischema_key_col.constraint_name,
#         ischema_key_col.ordinal_position,
#         ischema_key_col.table_schema,
#         ischema_key_col.table_name,
#         ischema_key_col.column_name
#     FROM
#         INFORMATION_SCHEMA.KEY_COLUMN_USAGE ischema_key_col
# ),
# index_info AS (
#     SELECT
#         sys.schemas.name AS index_schema,
#         sys.indexes.name AS index_name,
#         sys.index_columns.key_ordinal AS ordinal_position,
#         sys.schemas.name AS table_schema,
#         sys.objects.name AS table_name,
#         sys.columns.name AS column_name
#     FROM
#         sys.indexes
#         INNER JOIN
#         sys.objects ON
#             sys.objects.object_id = sys.indexes.object_id
#         INNER JOIN
#         sys.schemas ON
#             sys.schemas.schema_id = sys.objects.schema_id
#         INNER JOIN
#         sys.index_columns ON
#             sys.index_columns.object_id = sys.objects.object_id
#             AND sys.index_columns.index_id = sys.indexes.index_id
#         INNER JOIN
#         sys.columns ON
#             sys.columns.object_id = sys.indexes.object_id
#             AND sys.columns.column_id = sys.index_columns.column_id
# )
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         constraint_info.table_schema AS referred_table_schema,
#         constraint_info.table_name AS referred_table_name,
#         constraint_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN constraint_info ON
#             constraint_info.constraint_schema =
#                 fk_info.unique_constraint_schema
#             AND constraint_info.constraint_name =
#                 fk_info.unique_constraint_name
#             AND constraint_info.ordinal_position = fk_info.ordinal_position
#     UNION
#     SELECT
#         fk_info.constraint_schema,
#         fk_info.constraint_name,
#         fk_info.ordinal_position,
#         fk_info.constrained_column,
#         index_info.table_schema AS referred_table_schema,
#         index_info.table_name AS referred_table_name,
#         index_info.column_name AS referred_column,
#         fk_info.match_option,
#         fk_info.update_rule,
#         fk_info.delete_rule
#     FROM
#         fk_info INNER JOIN index_info ON
#             index_info.index_schema = fk_info.unique_constraint_schema
#             AND index_info.index_name = fk_info.unique_constraint_name
#             AND index_info.ordinal_position = fk_info.ordinal_position
#
#     ORDER BY fk_info.constraint_schema, fk_info.constraint_name,
#         fk_info.ordinal_position
#
# 2025-07-24 00:49:20,485 INFO sqlalchemy.engine.Engine [cached since 3.091s ago] ('support_tickets', 'dbo')
# 2025-07-24 00:49:20,490 INFO sqlalchemy.engine.Engine
# select
#     ind.index_id,
#     ind.is_unique,
#     ind.name,
#     ind.type,
#     ind.filter_definition
# from
#     sys.indexes as ind
# join sys.tables as tab on
#     ind.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#     and ind.is_primary_key = 0
#     and ind.type != 0
# order by
#     ind.name
#
# 2025-07-24 00:49:20,491 INFO sqlalchemy.engine.Engine [cached since 3.082s ago] ('support_tickets', 'dbo')
# 2025-07-24 00:49:20,493 INFO sqlalchemy.engine.Engine
# select
#     ind_col.index_id,
#     col.name,
#     ind_col.is_included_column
# from
#     sys.columns as col
# join sys.tables as tab on
#     tab.object_id = col.object_id
# join sys.index_columns as ind_col on
#     ind_col.column_id = col.column_id
#     and ind_col.object_id = tab.object_id
# join sys.schemas as sch on
#     sch.schema_id = tab.schema_id
# where
#     tab.name = CAST(? AS NVARCHAR(max))
#     and sch.name = CAST(? AS NVARCHAR(max))
#
# 2025-07-24 00:49:20,494 INFO sqlalchemy.engine.Engine [cached since 3.077s ago] ('support_tickets', 'dbo')
# 2025-07-24 00:49:20,498 INFO sqlalchemy.engine.Engine
#             SELECT cast(com.value as nvarchar(max))
#             FROM fn_listextendedproperty('MS_Description',
#                 'schema', CAST(? AS NVARCHAR(max)), 'table', CAST(? AS NVARCHAR(max)), NULL, NULL
#             ) as com;
#
# 2025-07-24 00:49:20,500 INFO sqlalchemy.engine.Engine [cached since 3.071s ago] ('dbo', 'support_tickets')
# 2025-07-24 00:49:20,502 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max))
# 2025-07-24 00:49:20,503 INFO sqlalchemy.engine.Engine [cached since 3.067s ago] ('BASE TABLE', 'VIEW', 'support_tickets')
# 2025-07-24 00:49:20,505 INFO sqlalchemy.engine.Engine
# DROP TABLE dbo.support_tickets
# 2025-07-24 00:49:20,506 INFO sqlalchemy.engine.Engine [no key 0.00087s] ()
# 2025-07-24 00:49:20,510 INFO sqlalchemy.engine.Engine
# CREATE TABLE dbo.support_tickets (
# 	ticket_id VARCHAR(max) NULL,
# 	customer_id BIGINT NULL,
# 	issue_type VARCHAR(max) NULL,
# 	opened_date DATETIME NULL,
# 	resolved_date DATETIME NULL,
# 	satisfaction_score FLOAT(53) NULL
# )
#
#
# 2025-07-24 00:49:20,511 INFO sqlalchemy.engine.Engine [no key 0.00086s] ()
# 2025-07-24 00:49:20,587 INFO sqlalchemy.engine.Engine INSERT INTO dbo.support_tickets (ticket_id, customer_id, issue_type, opened_date, resolved_date, satisfaction_score) VALUES (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ... 6752 characters truncated ... , (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?)
# 2025-07-24 00:49:20,588 INFO sqlalchemy.engine.Engine [generated in 0.00252s (insertmanyvalues) 1/3 (unordered)] ('TCKT-1', 81, 'Feature Request', datetime.datetime(2023, 2, 3, 0, 0), datetime.datetime(2023, 2, 3, 0, 0), 4.0, 'TCKT-2', 83, 'Login Issue', datetime.datetime(2023, 2, 9, 0, 0), datetime.datetime(2023, 2, 11, 0, 0), None, 'TCKT-3', 177, 'Bug', datetime.datetime(2023, 10, 13, 0, 0), datetime.datetime(2023, 10, 24, 0, 0), None, 'TCKT-4', 169, 'Feature Request', datetime.datetime(2023, 3, 27, 0, 0), datetime.datetime(2023, 4, 7, 0, 0), 3.0, 'TCKT-5', 50, 'INVALID', datetime.datetime(2023, 5, 11, 0, 0), None, 5.0, 'TCKT-6', 91, 'Login Issue', datetime.datetime(2023, 9, 18, 0, 0), None, None, 'TCKT-7', 187, 'Billing', datetime.datetime(2024, 1, 13, 0, 0), datetime.datetime(2024, 1, 23, 0, 0), 4.0, 'TCKT-8', 70, 'Other', datetime.datetime(2024, 1, 3, 0, 0), datetime.datetime(2024, 1, 15, 0, 0), 2.0, 'TCKT-9', 171 ... 1994 parameters truncated ... datetime.datetime(2023, 5, 21, 0, 0), 1.0, 'TCKT-342', 30, 'Bug', datetime.datetime(2024, 4, 24, 0, 0), datetime.datetime(2024, 4, 24, 0, 0), 3.0, 'TCKT-343', 82, 'Other', datetime.datetime(2024, 2, 4, 0, 0), datetime.datetime(2024, 2, 8, 0, 0), None, 'TCKT-344', 152, 'Billing', datetime.datetime(2023, 3, 9, 0, 0), datetime.datetime(2023, 3, 9, 0, 0), 4.0, 'TCKT-345', 31, 'Login Issue', datetime.datetime(2023, 11, 24, 0, 0), datetime.datetime(2023, 12, 5, 0, 0), 5.0, 'TCKT-346', 154, 'Other', datetime.datetime(2024, 1, 24, 0, 0), datetime.datetime(2024, 1, 31, 0, 0), None, 'TCKT-347', 5, 'Other', datetime.datetime(2024, 3, 11, 0, 0), None, 1.0, 'TCKT-348', 74, 'Other', datetime.datetime(2024, 4, 10, 0, 0), datetime.datetime(2024, 4, 20, 0, 0), 1.0, 'TCKT-349', 86, 'Billing', datetime.datetime(2024, 3, 22, 0, 0), datetime.datetime(2024, 3, 25, 0, 0), 3.0)
# 2025-07-24 00:49:20,892 INFO sqlalchemy.engine.Engine INSERT INTO dbo.support_tickets (ticket_id, customer_id, issue_type, opened_date, resolved_date, satisfaction_score) VALUES (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ... 6752 characters truncated ... , (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?)
# 2025-07-24 00:49:20,893 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (unordered)] ('TCKT-350', 121, 'Bug', datetime.datetime(2023, 10, 12, 0, 0), datetime.datetime(2023, 10, 26, 0, 0), None, 'TCKT-351', 141, 'Other', datetime.datetime(2023, 1, 19, 0, 0), None, None, 'TCKT-352', 157, 'Feature Request', datetime.datetime(2023, 4, 25, 0, 0), None, 3.0, 'TCKT-353', 144, 'Feature Request', datetime.datetime(2023, 11, 25, 0, 0), datetime.datetime(2023, 11, 25, 0, 0), 2.0, 'TCKT-354', 143, 'Other', datetime.datetime(2023, 10, 27, 0, 0), datetime.datetime(2023, 10, 31, 0, 0), None, 'TCKT-355', 186, 'INVALID', datetime.datetime(2024, 4, 8, 0, 0), datetime.datetime(2024, 4, 16, 0, 0), 2.0, 'TCKT-356', 185, 'Other', datetime.datetime(2023, 7, 26, 0, 0), datetime.datetime(2023, 7, 26, 0, 0), 3.0, 'TCKT-357', 83, None, datetime.datetime(2023, 6, 26, 0, 0), datetime.datetime(2023, 7, 7, 0, 0), 3.0, 'TCKT-358', 197 ... 1994 parameters truncated ... datetime.datetime(2023, 10, 20, 0, 0), 4.0, 'TCKT-691', 163, 'Feature Request', datetime.datetime(2024, 2, 2, 0, 0), datetime.datetime(2024, 2, 12, 0, 0), 1.0, 'TCKT-692', 103, 'Other', datetime.datetime(2023, 9, 18, 0, 0), None, 2.0, 'TCKT-693', 121, None, datetime.datetime(2023, 4, 9, 0, 0), datetime.datetime(2023, 4, 23, 0, 0), None, 'TCKT-694', 35, None, datetime.datetime(2023, 3, 3, 0, 0), datetime.datetime(2023, 3, 10, 0, 0), 1.0, 'TCKT-695', 47, None, datetime.datetime(2023, 6, 6, 0, 0), None, 2.0, 'TCKT-696', 70, 'Feature Request', datetime.datetime(2023, 2, 18, 0, 0), datetime.datetime(2023, 2, 25, 0, 0), 1.0, 'TCKT-697', 173, 'Login Issue', datetime.datetime(2024, 4, 12, 0, 0), datetime.datetime(2024, 4, 19, 0, 0), 3.0, 'TCKT-698', 25, 'Billing', datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 4, 10, 0, 0), 2.0)
# 2025-07-24 00:49:21,056 INFO sqlalchemy.engine.Engine INSERT INTO dbo.support_tickets (ticket_id, customer_id, issue_type, opened_date, resolved_date, satisfaction_score) VALUES (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ... 1812 characters truncated ... , (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?)
# 2025-07-24 00:49:21,057 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (unordered)] ('TCKT-699', 195, 'Login Issue', datetime.datetime(2023, 10, 11, 0, 0), datetime.datetime(2023, 10, 19, 0, 0), None, 'TCKT-700', 41, 'Other', datetime.datetime(2023, 12, 21, 0, 0), datetime.datetime(2024, 1, 1, 0, 0), None, 'TCKT-701', 79, 'Other', datetime.datetime(2023, 8, 13, 0, 0), datetime.datetime(2023, 8, 15, 0, 0), None, 'TCKT-702', 110, 'Login Issue', datetime.datetime(2023, 12, 3, 0, 0), None, 3.0, 'TCKT-703', 157, 'Bug', datetime.datetime(2024, 2, 15, 0, 0), datetime.datetime(2024, 2, 18, 0, 0), 3.0, 'TCKT-704', 159, 'Login Issue', datetime.datetime(2023, 10, 4, 0, 0), datetime.datetime(2023, 10, 6, 0, 0), 4.0, 'TCKT-705', 82, 'Login Issue', datetime.datetime(2023, 6, 9, 0, 0), datetime.datetime(2023, 6, 13, 0, 0), 3.0, 'TCKT-706', 176, None, datetime.datetime(2023, 11, 21, 0, 0), datetime.datetime(2023, 11, 26, 0, 0), 1.0, 'TCKT-707', 200 ... 512 parameters truncated ... datetime.datetime(2023, 5, 11, 0, 0), 3.0, 'TCKT-793', 138, 'Feature Request', datetime.datetime(2024, 4, 13, 0, 0), datetime.datetime(2024, 4, 26, 0, 0), 4.0, 'TCKT-794', 78, 'Other', datetime.datetime(2023, 2, 18, 0, 0), datetime.datetime(2023, 2, 24, 0, 0), 1.0, 'TCKT-795', 173, 'Bug', datetime.datetime(2023, 4, 7, 0, 0), None, 3.0, 'TCKT-796', 69, 'INVALID', datetime.datetime(2024, 4, 6, 0, 0), datetime.datetime(2024, 4, 19, 0, 0), 5.0, 'TCKT-797', 21, 'Login Issue', datetime.datetime(2023, 6, 28, 0, 0), datetime.datetime(2023, 7, 9, 0, 0), None, 'TCKT-798', 126, 'Login Issue', datetime.datetime(2023, 10, 9, 0, 0), datetime.datetime(2023, 10, 19, 0, 0), 5.0, 'TCKT-799', 148, 'Feature Request', datetime.datetime(2023, 9, 25, 0, 0), datetime.datetime(2023, 9, 27, 0, 0), 5.0, 'TCKT-800', 85, 'INVALID', datetime.datetime(2023, 7, 4, 0, 0), datetime.datetime(2023, 7, 7, 0, 0), 3.0)
# 2025-07-24 00:49:21,101 INFO sqlalchemy.engine.Engine COMMIT
# 102
